# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('Height-Weight data.csv') #load the dataset

# %%
df.head()
# Out:
#       Height      Weight
# 0  73.847017  241.893563
# 1  68.781904  162.310473
# 2  74.110105  212.740856
# 3  71.730978  220.042470
# 4  69.881796  206.349801

# %%
df.shape  #size of the dataset fisrt one(3501) is row and second one(2) is column
# Out:
# (3501, 2)

# %%
plt.scatter(df.Height , df.Weight)  #data analysis  (Scatter plot is a data visualization function)
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('Measurement table')
# Out:
# Text(0.5, 1.0, 'Measurement table')

# %%
x = df.drop('Weight', axis=1)  #by using the drop function we can extract any features of the dataset #axis=1 cause we want to drop a column and when we want t0 drop a row then axis =0
y = df[['Weight']]

# %%
x.head()
# Out:
#       Height
# 0  73.847017
# 1  68.781904
# 2  74.110105
# 3  71.730978
# 4  69.881796

# %%
y.head()
# Out:
#        Weight
# 0  241.893563
# 1  162.310473
# 2  212.740856
# 3  220.042470
# 4  206.349801

# %%
x.mean()  #mean value of x
# Out:
# Height    69.024411
# dtype: float64

# %%
y.mean()  #mean value of y
# Out:
# Weight    186.891258
# dtype: float64

# %%
from sklearn.model_selection import train_test_split  #seperate the training and testing data

# %%
train, test = train_test_split(df, test_size=.25)  #testing data25%

# %%
train.shape  #if we practice as train.shape and test.shape then both the column are not separated so our purpose not servered.that why we use as  train.shape #if we practice as train.shape and test.shape then both the column are not separated so our purpose not servered.that why we use as xtrain, xtest, ytrain, ytest
# Out:
# (2625, 2)

# %%
test.shape
# Out:
# (876, 2)

# %%
train.head()
# Out:
#          Height      Weight
# 3181  70.962617  195.017206
# 3479  72.587375  189.104046
# 1950  62.273401  154.280691
# 1116  71.920222  202.609275
# 1456  62.294695  149.497252

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=.25, random_state=5) #testing data=25% bu using random_state we can fixed the data

# %%
xtrain.head()
# Out:
#          Height
# 496   62.178331
# 2530  67.273294
# 2082  71.522419
# 342   69.749523
# 2692  71.608560

# %%
ytrain.head()
# Out:
#           Weight
# 496   145.898842
# 2530  185.285082
# 2082  194.264264
# 342   193.476259
# 2692  193.070142

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()  #create a object

# %%
lr.fit(xtrain, ytrain) # training the model
# Out:
# LinearRegression()

# %%
m = lr.coef_  #calculation is slop m
m
# Out:
# array([[5.98892784]])

# %%
c = lr.intercept_  #calculation of c
c
# Out:
# array([-226.50261281])

# %%
yp = (m*200)+c  #y=mx+c   prediction
yp
# Out:
# array([[971.28295594]])

# %%
yp = (m*150)+c  #prediction
yp
# Out:
# array([[671.83656376]])

# %%
lr.predict([[275]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[1420.45254423]])

# %%
x.head()
# Out:
#       Height
# 0  73.847017
# 1  68.781904
# 2  74.110105
# 3  71.730978
# 4  69.881796

# %%
df['predicted_Weight'] = lr.predict(x)
df.head()
# Out:
#       Height      Weight  predicted_Weight
# 0  73.847017  241.893563        215.761844
# 1  68.781904  162.310473        185.427248
# 2  74.110105  212.740856        217.337461
# 3  71.730978  220.042470        203.089041
# 4  69.881796  206.349801        192.014420

# %%
plt.plot(x, df[['predicted_Weight']])      # plt.plot(x.squeeze(), df[['predicted_weight']])
plt.scatter(x, df[['predicted_Weight']])
plt.scatter(x, df[['Weight']])
